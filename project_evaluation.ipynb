# %% [markdown]
# ## Evaluate Results Elasticsearch

# %%
import sys
import os
module_path = os.path.abspath(os.path.join('performance_evaluation.py'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from performance_evaluation import print_trec_eval

# %%
print_trec_eval('data01/FIR-s05-training-qrels.txt', 'result/elasticsearch.run')
# Out:
# Results for result/elasticsearch.run
# mean success_at_1              0.1053
# mean success_at_5              0.2632
# mean success_at_10             0.3158
# mean precision_at_1            0.1053
# mean precision_at_5            0.07895
# mean precision_at_10           0.04737
# mean precision_at_50           0.01947
# mean precision_at_100          0.01395
# mean precision_at_recall_0     0.2015
# mean precision_at_recall_10    0.1898
# mean precision_at_recall_20    0.1683
# mean precision_at_recall_30    0.1333
# mean precision_at_recall_40    0.1236
# mean precision_at_recall_50    0.1227
# mean precision_at_recall_60    0.08744
# mean precision_at_recall_70    0.08435
# mean precision_at_recall_80    0.05999
# mean precision_at_recall_90    0.05803
# mean precision_at_recall_100   0.05803
# mean average_precision         0.1116

# %% [markdown]
# ## Evaluate Results bio BERT

# %%
print_trec_eval('data01/trec-updated.qrels', 'result/bio-bert.run')
# Out:
# Results for result/bio-bert.run
# mean success_at_1              0.0
# mean success_at_5              0.05263
# mean success_at_10             0.05263
# mean precision_at_1            0.0
# mean precision_at_5            0.01053
# mean precision_at_10           0.007895
# mean precision_at_50           0.003158
# mean precision_at_100          0.002895
# mean precision_at_recall_0     0.02105
# mean precision_at_recall_10    0.01023
# mean precision_at_recall_20    0.004856
# mean precision_at_recall_30    0.002488
# mean precision_at_recall_40    0.001665
# mean precision_at_recall_50    0.001581
# mean precision_at_recall_60    2.779e-05
# mean precision_at_recall_70    2.779e-05
# mean precision_at_recall_80    2.779e-05
# mean precision_at_recall_90    2.779e-05
# mean precision_at_recall_100   2.779e-05
# mean average_precision         0.003159

# %%
## Evaluate Results pubmed BERT

# %%
print_trec_eval('data01/trec-updated.qrels', 'result/pubmed-bert.run')
# Out:
# Results for result/pubmed-bert.run
# mean success_at_1              0.0
# mean success_at_5              0.02632
# mean success_at_10             0.05263
# mean precision_at_1            0.0
# mean precision_at_5            0.005263
# mean precision_at_10           0.005263
# mean precision_at_50           0.004737
# mean precision_at_100          0.003421
# mean precision_at_recall_0     0.01507
# mean precision_at_recall_10    0.01404
# mean precision_at_recall_20    0.009414
# mean precision_at_recall_30    0.003211
# mean precision_at_recall_40    0.002817
# mean precision_at_recall_50    0.00276
# mean precision_at_recall_60    0.0005251
# mean precision_at_recall_70    0.0001671
# mean precision_at_recall_80    0.0001671
# mean precision_at_recall_90    0.0001671
# mean precision_at_recall_100   0.0001671
# mean average_precision         0.003758

# %%
## Evaluate Results normal BERT

# %%
print_trec_eval('data01/trec-updated.qrels', 'result/normal-bert.run')
# Out:
# Results for result/normal-bert.run
# mean success_at_1              0.0
# mean success_at_5              0.0
# mean success_at_10             0.05263
# mean precision_at_1            0.0
# mean precision_at_5            0.0
# mean precision_at_10           0.005263
# mean precision_at_50           0.002105
# mean precision_at_100          0.001579
# mean precision_at_recall_0     0.01079
# mean precision_at_recall_10    0.008289
# mean precision_at_recall_20    0.006362
# mean precision_at_recall_30    0.0006484
# mean precision_at_recall_40    0.0002879
# mean precision_at_recall_50    0.0001878
# mean precision_at_recall_60    0.0001056
# mean precision_at_recall_70    0.0001056
# mean precision_at_recall_80    0.0001056
# mean precision_at_recall_90    0.0001056
# mean precision_at_recall_100   0.0001056
# mean average_precision         0.002115
